# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
import sklearn, re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA as sklearnPCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
regex_square_brackets = re.compile(r'(\[)|(\])')

# %%
bugs = pd.read_csv('../datasets/lexical_semantic_preprocessed_mantis_bugs_less_columns.csv')
bug_notes = pd.read_csv('../datasets/lexical_semantic_preprocessed_mantis_bugnotes.csv')

# %%
bug_notes['bug_note'] = bug_notes['bug_note'].str.replace(regex_square_brackets, '')
bugs['additional_information'] = bugs['additional_information'].str.replace(regex_square_brackets, '')
bugs['description'] = bugs['description'].str.replace(regex_square_brackets, '')
bugs['summary'] = bugs['summary'].str.replace(regex_square_brackets, '')

# %%
df_bug_note_table = bug_notes.groupby(['bug_id'])['bug_note'].apply(','.join).to_frame('bug_notes').reset_index()
result = pd.merge(bugs, df_bug_note_table, how='left', left_on='id', right_on='bug_id')
result.fillna('', inplace=True)
result['textual_data'] = result['summary'] + ',' + result['description'] + ',' + result['additional_information'] + ',' + result['bug_notes']

# %%
max_features = 50
clustered = pd.DataFrame(columns=['id', 'reporter_id', 'severity', 'priority', 'cluster', 'cluster_#', 'cluster_dbscan_silhouette_mean'])
eps = 0.03
# decrease features by 500 in each iteration
# for each selection of max_features try to find good clusters
# apply recursion to increase eps by 0.01 at each step

# %%
def check_cluster_qualities(df, clustered_df, bugs_df, max_f, eps):
    clusters_found = False
    count = clustered_df['cluster_#'].max()
    if not count:
        
    for clu in set(df['cluster_dbscan']):
        if clu >= 0:
            temp_df = df[df['cluster_dbscan']==clu]
            if eps <= 0.2:
                decision_boundry = 0.5
            else:
                decision_boundry = 0.4
            if temp_df['cluster_dbscan_silhouette'].mean() > decision_boundry:
                count += 1
                clusters_found= True
                intracluster_ids = bugs_df[bugs_df['id'].isin(temp_df['id'])][['id', 'reporter_id', 'severity', 'priority']]
                intracluster_ids['cluster'] = '{}_{}_{}'.format(max_f, eps, clu, count)
                intracluster_ids['cluster_#'] = count
                intracluster_ids['cluster_dbscan_silhouette_mean'] = temp_df['cluster_dbscan_silhouette'].mean()
                clustered_df = pd.concat([clustered_df, intracluster_ids], axis=0)
                print "{} issues clustered".format(len(clustered_df))
    return clustered_df, clusters_found

# %%
eps_iterations = True
while(eps_iterations):
    max_features = 50
    while(True):
        bug_bugnotes_df = result[['id', 'textual_data']].copy()
        bug_bugnotes_df = bug_bugnotes_df[~(bug_bugnotes_df['id'].isin(clustered['id']))]
        vectorizer = TfidfVectorizer(min_df=2, max_df=0.9, max_features=max_features, stop_words='english')
        X = vectorizer.fit_transform(bug_bugnotes_df['textual_data'])
        print "Iteration for the combination max_features: {} and eps: {} started ...".format(max_features, eps)
        dbscan = DBSCAN(eps=eps, metric='cosine').fit_predict(X)
        bug_bugnotes_df['cluster_dbscan'] = dbscan
        clusters_found = False
        if len(set(bug_bugnotes_df['cluster_dbscan'])) > 1:
            sample_silhouette_values = silhouette_samples(X, dbscan)
            bug_bugnotes_df['cluster_dbscan_silhouette'] = sample_silhouette_values
            ### Search for good clusters
            clustered, clusters_found = check_cluster_qualities(bug_bugnotes_df, clustered, bugs, max_features, eps)
            #if clusters_found:
             #   max_features = 50
              #  eps = 0.03
        if not clusters_found:
            if max_features <= 100:
                max_features += 20
            elif max_features <= 1000:
                max_features += 100
            #elif max_features <= 2000:
            #    max_features += 500
            #elif max_features <= 10000:
            #    max_features += 2000
            elif max_features <= 20000:
                max_features += 5000
            else:
                break
    eps += 0.03
    if eps > 0.4:
        eps_iterations = False
# Out:
# Iteration for the combination max_features: 50 and eps: 0.03 started ...
# 75 issues clustered
# 82 issues clustered
# 88 issues clustered
# 107 issues clustered
# 113 issues clustered
# 121 issues clustered
# 143 issues clustered
# 159 issues clustered
# 165 issues clustered
# 183 issues clustered
# 219 issues clustered
# 236 issues clustered
# 253 issues clustered
# 264 issues clustered
# 276 issues clustered
# 292 issues clustered
# 297 issues clustered
# 315 issues clustered
# 323 issues clustered
# 328 issues clustered
# 335 issues clustered
# 349 issues clustered
# 370 issues clustered
# 375 issues clustered
# 387 issues clustered
# 392 issues clustered
# 404 issues clustered
# 413 issues clustered
# 442 issues clustered
# 449 issues clustered
# 456 issues clustered
# 469 issues clustered
# 476 issues clustered
# 500 issues clustered
# 510 issues clustered
# 517 issues clustered
# 525 issues clustered
# 531 issues clustered
# 541 issues clustered
# 546 issues clustered
# 551 issues clustered
# 556 issues clustered
# 570 issues clustered
# 575 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.03 started ...
# 584 issues clustered
# 590 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.03 started ...
# Iteration for the combination max_features: 70 and eps: 0.03 started ...
# 596 issues clustered
# 606 issues clustered
# 611 issues clustered
# 616 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.03 started ...
# Iteration for the combination max_features: 90 and eps: 0.03 started ...
# 622 issues clustered
# 627 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.03 started ...
# Iteration for the combination max_features: 110 and eps: 0.03 started ...
# Iteration for the combination max_features: 210 and eps: 0.03 started ...
# Iteration for the combination max_features: 310 and eps: 0.03 started ...
# Iteration for the combination max_features: 410 and eps: 0.03 started ...
# 634 issues clustered
# Iteration for the combination max_features: 410 and eps: 0.03 started ...
# Iteration for the combination max_features: 510 and eps: 0.03 started ...
# Iteration for the combination max_features: 610 and eps: 0.03 started ...
# Iteration for the combination max_features: 710 and eps: 0.03 started ...
# Iteration for the combination max_features: 810 and eps: 0.03 started ...
# Iteration for the combination max_features: 910 and eps: 0.03 started ...
# Iteration for the combination max_features: 1010 and eps: 0.03 started ...
# Iteration for the combination max_features: 6010 and eps: 0.03 started ...
# Iteration for the combination max_features: 11010 and eps: 0.03 started ...
# Iteration for the combination max_features: 16010 and eps: 0.03 started ...
# Iteration for the combination max_features: 21010 and eps: 0.03 started ...
# Iteration for the combination max_features: 50 and eps: 0.06 started ...
# 649 issues clustered
# 656 issues clustered
# 661 issues clustered
# 669 issues clustered
# 703 issues clustered
# 708 issues clustered
# 714 issues clustered
# 719 issues clustered
# 732 issues clustered
# 738 issues clustered
# 752 issues clustered
# 757 issues clustered
# 764 issues clustered
# 771 issues clustered
# 780 issues clustered
# 785 issues clustered
# 790 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.06 started ...
# 807 issues clustered
# 812 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.06 started ...
# 819 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.06 started ...
# Iteration for the combination max_features: 70 and eps: 0.06 started ...
# Iteration for the combination max_features: 90 and eps: 0.06 started ...
# 825 issues clustered
# 833 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.06 started ...
# Iteration for the combination max_features: 110 and eps: 0.06 started ...
# 838 issues clustered
# 844 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.06 started ...
# Iteration for the combination max_features: 210 and eps: 0.06 started ...
# Iteration for the combination max_features: 310 and eps: 0.06 started ...
# 852 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.06 started ...
# Iteration for the combination max_features: 410 and eps: 0.06 started ...
# Iteration for the combination max_features: 510 and eps: 0.06 started ...
# Iteration for the combination max_features: 610 and eps: 0.06 started ...
# Iteration for the combination max_features: 710 and eps: 0.06 started ...
# Iteration for the combination max_features: 810 and eps: 0.06 started ...
# Iteration for the combination max_features: 910 and eps: 0.06 started ...
# Iteration for the combination max_features: 1010 and eps: 0.06 started ...
# Iteration for the combination max_features: 6010 and eps: 0.06 started ...
# Iteration for the combination max_features: 11010 and eps: 0.06 started ...
# Iteration for the combination max_features: 16010 and eps: 0.06 started ...
# Iteration for the combination max_features: 21010 and eps: 0.06 started ...
# Iteration for the combination max_features: 50 and eps: 0.09 started ...
# 888 issues clustered
# 894 issues clustered
# 899 issues clustered
# 906 issues clustered
# 911 issues clustered
# 919 issues clustered
# 925 issues clustered
# 930 issues clustered
# 935 issues clustered
# 940 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.09 started ...
# Iteration for the combination max_features: 70 and eps: 0.09 started ...
# 977 issues clustered
# 987 issues clustered
# 994 issues clustered
# 999 issues clustered
# 1005 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.09 started ...
# Iteration for the combination max_features: 90 and eps: 0.09 started ...
# 1010 issues clustered
# 1016 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.09 started ...
# 1022 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.09 started ...
# Iteration for the combination max_features: 110 and eps: 0.09 started ...
# 1028 issues clustered
# 1042 issues clustered
# 1050 issues clustered
# 1057 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.09 started ...
# 1062 issues clustered
# 1071 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.09 started ...
# Iteration for the combination max_features: 210 and eps: 0.09 started ...
# 1081 issues clustered
# 1087 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.09 started ...
# Iteration for the combination max_features: 310 and eps: 0.09 started ...
# 1092 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.09 started ...
# 1109 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.09 started ...
# Iteration for the combination max_features: 410 and eps: 0.09 started ...
# Iteration for the combination max_features: 510 and eps: 0.09 started ...
# 1114 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.09 started ...
# Iteration for the combination max_features: 610 and eps: 0.09 started ...
# 1121 issues clustered
# Iteration for the combination max_features: 610 and eps: 0.09 started ...
# Iteration for the combination max_features: 710 and eps: 0.09 started ...
# Iteration for the combination max_features: 810 and eps: 0.09 started ...
# Iteration for the combination max_features: 910 and eps: 0.09 started ...
# Iteration for the combination max_features: 1010 and eps: 0.09 started ...
# Iteration for the combination max_features: 6010 and eps: 0.09 started ...
# Iteration for the combination max_features: 11010 and eps: 0.09 started ...
# Iteration for the combination max_features: 16010 and eps: 0.09 started ...
# Iteration for the combination max_features: 21010 and eps: 0.09 started ...
# Iteration for the combination max_features: 50 and eps: 0.12 started ...
# 1126 issues clustered
# 1131 issues clustered
# 1139 issues clustered
# 1146 issues clustered
# 1152 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.12 started ...
# 1157 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.12 started ...
# Iteration for the combination max_features: 70 and eps: 0.12 started ...
# 1163 issues clustered
# 1168 issues clustered
# 1173 issues clustered
# 1178 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.12 started ...
# 1189 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.12 started ...
# Iteration for the combination max_features: 90 and eps: 0.12 started ...
# 1199 issues clustered
# 1204 issues clustered
# 1213 issues clustered
# 1219 issues clustered
# 1224 issues clustered
# 1229 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.12 started ...
# 1234 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.12 started ...
# Iteration for the combination max_features: 110 and eps: 0.12 started ...
# 1241 issues clustered
# 1246 issues clustered
# 1251 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.12 started ...
# Iteration for the combination max_features: 210 and eps: 0.12 started ...
# 1256 issues clustered
# 1261 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.12 started ...
# Iteration for the combination max_features: 310 and eps: 0.12 started ...
# 1266 issues clustered
# 1273 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.12 started ...
# Iteration for the combination max_features: 410 and eps: 0.12 started ...
# Iteration for the combination max_features: 510 and eps: 0.12 started ...
# 1286 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.12 started ...
# 1291 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.12 started ...
# Iteration for the combination max_features: 610 and eps: 0.12 started ...
# Iteration for the combination max_features: 710 and eps: 0.12 started ...
# Iteration for the combination max_features: 810 and eps: 0.12 started ...
# Iteration for the combination max_features: 910 and eps: 0.12 started ...
# Iteration for the combination max_features: 1010 and eps: 0.12 started ...
# Iteration for the combination max_features: 6010 and eps: 0.12 started ...
# Iteration for the combination max_features: 11010 and eps: 0.12 started ...
# Iteration for the combination max_features: 16010 and eps: 0.12 started ...
# Iteration for the combination max_features: 21010 and eps: 0.12 started ...
# Iteration for the combination max_features: 50 and eps: 0.15 started ...
# 1298 issues clustered
# 1303 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.15 started ...
# Iteration for the combination max_features: 70 and eps: 0.15 started ...
# 1308 issues clustered
# 1313 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.15 started ...
# Iteration for the combination max_features: 90 and eps: 0.15 started ...
# 1319 issues clustered
# 1325 issues clustered
# 1328 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.15 started ...
# 1332 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.15 started ...
# Iteration for the combination max_features: 110 and eps: 0.15 started ...
# 1338 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.15 started ...
# Iteration for the combination max_features: 210 and eps: 0.15 started ...
# 1349 issues clustered
# 1354 issues clustered
# 1359 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.15 started ...
# Iteration for the combination max_features: 310 and eps: 0.15 started ...
# 1364 issues clustered
# 1370 issues clustered
# 1376 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.15 started ...
# Iteration for the combination max_features: 410 and eps: 0.15 started ...
# 1381 issues clustered
# Iteration for the combination max_features: 410 and eps: 0.15 started ...
# Iteration for the combination max_features: 510 and eps: 0.15 started ...
# 1388 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.15 started ...
# Iteration for the combination max_features: 610 and eps: 0.15 started ...
# 1397 issues clustered
# Iteration for the combination max_features: 610 and eps: 0.15 started ...
# Iteration for the combination max_features: 710 and eps: 0.15 started ...
# 1402 issues clustered
# 1407 issues clustered
# Iteration for the combination max_features: 710 and eps: 0.15 started ...
# 1412 issues clustered
# Iteration for the combination max_features: 710 and eps: 0.15 started ...
# Iteration for the combination max_features: 810 and eps: 0.15 started ...
# Iteration for the combination max_features: 910 and eps: 0.15 started ...
# Iteration for the combination max_features: 1010 and eps: 0.15 started ...
# Iteration for the combination max_features: 6010 and eps: 0.15 started ...
# 1420 issues clustered
# Iteration for the combination max_features: 6010 and eps: 0.15 started ...
# Iteration for the combination max_features: 11010 and eps: 0.15 started ...
# Iteration for the combination max_features: 16010 and eps: 0.15 started ...
# Iteration for the combination max_features: 21010 and eps: 0.15 started ...
# Iteration for the combination max_features: 50 and eps: 0.18 started ...
# 1425 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.18 started ...
# Iteration for the combination max_features: 70 and eps: 0.18 started ...
# 1431 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.18 started ...
# Iteration for the combination max_features: 90 and eps: 0.18 started ...
# 1436 issues clustered
# 1439 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.18 started ...
# Iteration for the combination max_features: 110 and eps: 0.18 started ...
# Iteration for the combination max_features: 210 and eps: 0.18 started ...
# 1445 issues clustered
# 1451 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.18 started ...
# Iteration for the combination max_features: 310 and eps: 0.18 started ...
# 1456 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.18 started ...
# Iteration for the combination max_features: 410 and eps: 0.18 started ...
# Iteration for the combination max_features: 510 and eps: 0.18 started ...
# Iteration for the combination max_features: 610 and eps: 0.18 started ...
# 1461 issues clustered
# 1469 issues clustered
# Iteration for the combination max_features: 610 and eps: 0.18 started ...
# Iteration for the combination max_features: 710 and eps: 0.18 started ...
# 1474 issues clustered
# Iteration for the combination max_features: 710 and eps: 0.18 started ...
# Iteration for the combination max_features: 810 and eps: 0.18 started ...
# 1479 issues clustered
# 1484 issues clustered
# Iteration for the combination max_features: 810 and eps: 0.18 started ...
# Iteration for the combination max_features: 910 and eps: 0.18 started ...
# Iteration for the combination max_features: 1010 and eps: 0.18 started ...
# 1489 issues clustered
# Iteration for the combination max_features: 1010 and eps: 0.18 started ...
# Iteration for the combination max_features: 6010 and eps: 0.18 started ...
# 1496 issues clustered
# 1501 issues clustered
# Iteration for the combination max_features: 6010 and eps: 0.18 started ...
# Iteration for the combination max_features: 11010 and eps: 0.18 started ...
# Iteration for the combination max_features: 16010 and eps: 0.18 started ...
# Iteration for the combination max_features: 21010 and eps: 0.18 started ...
# Iteration for the combination max_features: 50 and eps: 0.21 started ...
# 1504 issues clustered
# 1509 issues clustered
# 1511 issues clustered
# 1515 issues clustered
# 1520 issues clustered
# 1526 issues clustered
# 1531 issues clustered
# 1534 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.21 started ...
# 1539 issues clustered
# 1544 issues clustered
# 1549 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.21 started ...
# 1558 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.21 started ...
# Iteration for the combination max_features: 70 and eps: 0.21 started ...
# 1574 issues clustered
# 1579 issues clustered
# 1590 issues clustered
# 1599 issues clustered
# 1604 issues clustered
# 1609 issues clustered
# 1614 issues clustered
# 1618 issues clustered
# 1624 issues clustered
# 1629 issues clustered
# 1633 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.21 started ...
# 1645 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.21 started ...
# Iteration for the combination max_features: 90 and eps: 0.21 started ...
# 1650 issues clustered
# 1655 issues clustered
# 1671 issues clustered
# 1688 issues clustered
# 1696 issues clustered
# 1699 issues clustered
# 1704 issues clustered
# 1719 issues clustered
# 1729 issues clustered
# 1735 issues clustered
# 1746 issues clustered
# 1752 issues clustered
# 1757 issues clustered
# 1762 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.21 started ...
# 1826 issues clustered
# 1830 issues clustered
# 1836 issues clustered
# 1840 issues clustered
# 1845 issues clustered
# 1850 issues clustered
# 1854 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.21 started ...
# 1859 issues clustered
# 1864 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.21 started ...
# Iteration for the combination max_features: 110 and eps: 0.21 started ...
# 1877 issues clustered
# 1889 issues clustered
# 1897 issues clustered
# 1902 issues clustered
# 1906 issues clustered
# 1912 issues clustered
# 1924 issues clustered
# 1933 issues clustered
# 1939 issues clustered
# 1944 issues clustered
# 1950 issues clustered
# 1956 issues clustered
# 1961 issues clustered
# 1965 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.21 started ...
# 1976 issues clustered
# 2010 issues clustered
# 2014 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.21 started ...
# 2019 issues clustered
# 2051 issues clustered
# 2057 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.21 started ...
# Iteration for the combination max_features: 210 and eps: 0.21 started ...
# 2072 issues clustered
# 2085 issues clustered
# 2092 issues clustered
# 2100 issues clustered
# 2105 issues clustered
# 2110 issues clustered
# 2115 issues clustered
# 2123 issues clustered
# 2130 issues clustered
# 2136 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.21 started ...
# 2161 issues clustered
# 2179 issues clustered
# 2188 issues clustered
# 2194 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.21 started ...
# 2202 issues clustered
# 2210 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.21 started ...
# Iteration for the combination max_features: 310 and eps: 0.21 started ...
# 2281 issues clustered
# 2295 issues clustered
# 2302 issues clustered
# 2310 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.21 started ...
# 2317 issues clustered
# 2330 issues clustered
# 2336 issues clustered
# 2342 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.21 started ...
# 2367 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.21 started ...
# Iteration for the combination max_features: 410 and eps: 0.21 started ...
# 2372 issues clustered
# 2377 issues clustered
# 2382 issues clustered
# 2388 issues clustered
# Iteration for the combination max_features: 410 and eps: 0.21 started ...
# Iteration for the combination max_features: 510 and eps: 0.21 started ...
# 2413 issues clustered
# 2419 issues clustered
# 2428 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.21 started ...
# Iteration for the combination max_features: 610 and eps: 0.21 started ...
# 2434 issues clustered
# 2440 issues clustered
# 2455 issues clustered
# 2460 issues clustered
# 2465 issues clustered
# 2471 issues clustered
# Iteration for the combination max_features: 610 and eps: 0.21 started ...
# Iteration for the combination max_features: 710 and eps: 0.21 started ...
# 2476 issues clustered
# 2483 issues clustered
# Iteration for the combination max_features: 710 and eps: 0.21 started ...
# 2490 issues clustered
# Iteration for the combination max_features: 710 and eps: 0.21 started ...
# Iteration for the combination max_features: 810 and eps: 0.21 started ...
# Iteration for the combination max_features: 910 and eps: 0.21 started ...
# Iteration for the combination max_features: 1010 and eps: 0.21 started ...
# Iteration for the combination max_features: 6010 and eps: 0.21 started ...
# Iteration for the combination max_features: 11010 and eps: 0.21 started ...
# Iteration for the combination max_features: 16010 and eps: 0.21 started ...
# Iteration for the combination max_features: 21010 and eps: 0.21 started ...
# Iteration for the combination max_features: 50 and eps: 0.24 started ...
# 2492 issues clustered
# 2496 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.24 started ...
# 2501 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.24 started ...
# Iteration for the combination max_features: 70 and eps: 0.24 started ...
# 2507 issues clustered
# 2512 issues clustered
# 2518 issues clustered
# 2523 issues clustered
# 2531 issues clustered
# 2537 issues clustered
# 2541 issues clustered
# 2546 issues clustered
# 2551 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.24 started ...
# 2558 issues clustered
# 2566 issues clustered
# 2571 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.24 started ...
# 2577 issues clustered
# 2581 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.24 started ...
# Iteration for the combination max_features: 90 and eps: 0.24 started ...
# 2586 issues clustered
# 2592 issues clustered
# 2599 issues clustered
# 2604 issues clustered
# 2611 issues clustered
# 2618 issues clustered
# 2622 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.24 started ...
# Iteration for the combination max_features: 110 and eps: 0.24 started ...
# 2627 issues clustered
# 2632 issues clustered
# 2641 issues clustered
# 2649 issues clustered
# 2655 issues clustered
# 2660 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.24 started ...
# 2664 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.24 started ...
# 2669 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.24 started ...
# Iteration for the combination max_features: 210 and eps: 0.24 started ...
# 2674 issues clustered
# 2683 issues clustered
# 2688 issues clustered
# 2695 issues clustered
# 2700 issues clustered
# 2705 issues clustered
# 2711 issues clustered
# 2716 issues clustered
# 2725 issues clustered
# 2730 issues clustered
# 2735 issues clustered
# 2740 issues clustered
# 2747 issues clustered
# 2752 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.24 started ...
# 2757 issues clustered
# 2763 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.24 started ...
# 2768 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.24 started ...
# Iteration for the combination max_features: 310 and eps: 0.24 started ...
# 2780 issues clustered
# 2787 issues clustered
# 2793 issues clustered
# 2798 issues clustered
# 2803 issues clustered
# 2809 issues clustered
# 2815 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.24 started ...
# Iteration for the combination max_features: 410 and eps: 0.24 started ...
# Iteration for the combination max_features: 510 and eps: 0.24 started ...
# 2821 issues clustered
# 2830 issues clustered
# 2840 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.24 started ...
# 2845 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.24 started ...
# Iteration for the combination max_features: 610 and eps: 0.24 started ...
# 2852 issues clustered
# 2858 issues clustered
# 2864 issues clustered
# 2870 issues clustered
# 2875 issues clustered
# Iteration for the combination max_features: 610 and eps: 0.24 started ...
# Iteration for the combination max_features: 710 and eps: 0.24 started ...
# Iteration for the combination max_features: 810 and eps: 0.24 started ...
# 2882 issues clustered
# Iteration for the combination max_features: 810 and eps: 0.24 started ...
# Iteration for the combination max_features: 910 and eps: 0.24 started ...
# Iteration for the combination max_features: 1010 and eps: 0.24 started ...
# Iteration for the combination max_features: 6010 and eps: 0.24 started ...
# Iteration for the combination max_features: 11010 and eps: 0.24 started ...
# Iteration for the combination max_features: 16010 and eps: 0.24 started ...
# Iteration for the combination max_features: 21010 and eps: 0.24 started ...
# Iteration for the combination max_features: 50 and eps: 0.27 started ...
# 2891 issues clustered
# 2895 issues clustered
# 2897 issues clustered
# 2906 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.27 started ...
# Iteration for the combination max_features: 70 and eps: 0.27 started ...
# 2913 issues clustered
# 2920 issues clustered
# 2926 issues clustered
# 2931 issues clustered
# 2934 issues clustered
# 2939 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.27 started ...
# Iteration for the combination max_features: 90 and eps: 0.27 started ...
# 2945 issues clustered
# 2958 issues clustered
# 2963 issues clustered
# 2967 issues clustered
# 2974 issues clustered
# 2977 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.27 started ...
# 2982 issues clustered
# 2987 issues clustered
# 2992 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.27 started ...
# Iteration for the combination max_features: 110 and eps: 0.27 started ...
# 3008 issues clustered
# 3014 issues clustered
# 3022 issues clustered
# 3026 issues clustered
# 3029 issues clustered
# 3034 issues clustered
# 3046 issues clustered
# 3051 issues clustered
# 3056 issues clustered
# 3062 issues clustered
# 3067 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.27 started ...
# 3071 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.27 started ...
# Iteration for the combination max_features: 210 and eps: 0.27 started ...
# 3081 issues clustered
# 3087 issues clustered
# 3092 issues clustered
# 3097 issues clustered
# 3101 issues clustered
# 3106 issues clustered
# 3110 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.27 started ...
# 3117 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.27 started ...
# Iteration for the combination max_features: 310 and eps: 0.27 started ...
# 3121 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.27 started ...
# Iteration for the combination max_features: 410 and eps: 0.27 started ...
# 3126 issues clustered
# 3131 issues clustered
# 3138 issues clustered
# 3145 issues clustered
# 3151 issues clustered
# 3156 issues clustered
# Iteration for the combination max_features: 410 and eps: 0.27 started ...
# 3161 issues clustered
# Iteration for the combination max_features: 410 and eps: 0.27 started ...
# Iteration for the combination max_features: 510 and eps: 0.27 started ...
# 3169 issues clustered
# 3174 issues clustered
# 3179 issues clustered
# 3184 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.27 started ...
# 3189 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.27 started ...
# Iteration for the combination max_features: 610 and eps: 0.27 started ...
# 3194 issues clustered
# 3201 issues clustered
# Iteration for the combination max_features: 610 and eps: 0.27 started ...
# Iteration for the combination max_features: 710 and eps: 0.27 started ...
# Iteration for the combination max_features: 810 and eps: 0.27 started ...
# 3206 issues clustered
# 3214 issues clustered
# 3219 issues clustered
# Iteration for the combination max_features: 810 and eps: 0.27 started ...
# Iteration for the combination max_features: 910 and eps: 0.27 started ...
# Iteration for the combination max_features: 1010 and eps: 0.27 started ...
# Iteration for the combination max_features: 6010 and eps: 0.27 started ...
# 3224 issues clustered
# Iteration for the combination max_features: 6010 and eps: 0.27 started ...
# Iteration for the combination max_features: 11010 and eps: 0.27 started ...
# Iteration for the combination max_features: 16010 and eps: 0.27 started ...
# Iteration for the combination max_features: 21010 and eps: 0.27 started ...
# Iteration for the combination max_features: 50 and eps: 0.3 started ...
# 3226 issues clustered
# Iteration for the combination max_features: 50 and eps: 0.3 started ...
# Iteration for the combination max_features: 70 and eps: 0.3 started ...
# 3231 issues clustered
# 3235 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.3 started ...
# Iteration for the combination max_features: 90 and eps: 0.3 started ...
# 3240 issues clustered
# 3244 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.3 started ...
# Iteration for the combination max_features: 110 and eps: 0.3 started ...
# 3249 issues clustered
# 3254 issues clustered
# 3259 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.3 started ...
# 3263 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.3 started ...
# 3272 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.3 started ...
# 3276 issues clustered
# 3279 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.3 started ...
# Iteration for the combination max_features: 210 and eps: 0.3 started ...
# 3294 issues clustered
# 3299 issues clustered
# 3318 issues clustered
# 3321 issues clustered
# 3327 issues clustered
# 3330 issues clustered
# 3334 issues clustered
# 3339 issues clustered
# 3344 issues clustered
# 3349 issues clustered
# 3354 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.3 started ...
# 3361 issues clustered
# 3366 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.3 started ...
# Iteration for the combination max_features: 310 and eps: 0.3 started ...
# 3371 issues clustered
# 3380 issues clustered
# 3385 issues clustered
# 3390 issues clustered
# 3396 issues clustered
# 3401 issues clustered
# 3407 issues clustered
# 3410 issues clustered
# 3416 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.3 started ...
# 3423 issues clustered
# 3428 issues clustered
# 3433 issues clustered
# 3438 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.3 started ...
# 3443 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.3 started ...
# Iteration for the combination max_features: 410 and eps: 0.3 started ...
# 3454 issues clustered
# 3459 issues clustered
# 3464 issues clustered
# 3468 issues clustered
# 3473 issues clustered
# 3478 issues clustered
# Iteration for the combination max_features: 410 and eps: 0.3 started ...
# 3483 issues clustered
# Iteration for the combination max_features: 410 and eps: 0.3 started ...
# Iteration for the combination max_features: 510 and eps: 0.3 started ...
# 3488 issues clustered
# 3493 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.3 started ...
# Iteration for the combination max_features: 610 and eps: 0.3 started ...
# 3499 issues clustered
# 3504 issues clustered
# Iteration for the combination max_features: 610 and eps: 0.3 started ...
# Iteration for the combination max_features: 710 and eps: 0.3 started ...
# 3509 issues clustered
# 3513 issues clustered
# 3518 issues clustered
# Iteration for the combination max_features: 710 and eps: 0.3 started ...
# Iteration for the combination max_features: 810 and eps: 0.3 started ...
# 3523 issues clustered
# 3528 issues clustered
# Iteration for the combination max_features: 810 and eps: 0.3 started ...
# Iteration for the combination max_features: 910 and eps: 0.3 started ...
# 3533 issues clustered
# 3538 issues clustered
# Iteration for the combination max_features: 910 and eps: 0.3 started ...
# Iteration for the combination max_features: 1010 and eps: 0.3 started ...
# 3543 issues clustered
# Iteration for the combination max_features: 1010 and eps: 0.3 started ...
# Iteration for the combination max_features: 6010 and eps: 0.3 started ...
# 3548 issues clustered
# Iteration for the combination max_features: 6010 and eps: 0.3 started ...
# Iteration for the combination max_features: 11010 and eps: 0.3 started ...
# Iteration for the combination max_features: 16010 and eps: 0.3 started ...
# Iteration for the combination max_features: 21010 and eps: 0.3 started ...
# Iteration for the combination max_features: 50 and eps: 0.33 started ...
# Iteration for the combination max_features: 70 and eps: 0.33 started ...
# Iteration for the combination max_features: 90 and eps: 0.33 started ...
# 3550 issues clustered
# 3554 issues clustered
# 3559 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.33 started ...
# 3563 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.33 started ...
# Iteration for the combination max_features: 110 and eps: 0.33 started ...
# 3567 issues clustered
# 3571 issues clustered
# 3576 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.33 started ...
# Iteration for the combination max_features: 210 and eps: 0.33 started ...
# 3581 issues clustered
# 3587 issues clustered
# 3591 issues clustered
# 3598 issues clustered
# 3603 issues clustered
# 3609 issues clustered
# 3614 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.33 started ...
# 3624 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.33 started ...
# Iteration for the combination max_features: 310 and eps: 0.33 started ...
# 3629 issues clustered
# 3634 issues clustered
# 3639 issues clustered
# 3642 issues clustered
# 3647 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.33 started ...
# 3651 issues clustered
# 3654 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.33 started ...
# 3661 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.33 started ...
# Iteration for the combination max_features: 410 and eps: 0.33 started ...
# 3666 issues clustered
# 3671 issues clustered
# Iteration for the combination max_features: 410 and eps: 0.33 started ...
# 3676 issues clustered
# Iteration for the combination max_features: 410 and eps: 0.33 started ...
# Iteration for the combination max_features: 510 and eps: 0.33 started ...
# 3686 issues clustered
# 3691 issues clustered
# 3696 issues clustered
# 3701 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.33 started ...
# Iteration for the combination max_features: 610 and eps: 0.33 started ...
# 3711 issues clustered
# Iteration for the combination max_features: 610 and eps: 0.33 started ...
# 3716 issues clustered
# Iteration for the combination max_features: 610 and eps: 0.33 started ...
# Iteration for the combination max_features: 710 and eps: 0.33 started ...
# 3722 issues clustered
# 3727 issues clustered
# 3732 issues clustered
# Iteration for the combination max_features: 710 and eps: 0.33 started ...
# 3740 issues clustered
# Iteration for the combination max_features: 710 and eps: 0.33 started ...
# Iteration for the combination max_features: 810 and eps: 0.33 started ...
# 3745 issues clustered
# Iteration for the combination max_features: 810 and eps: 0.33 started ...
# Iteration for the combination max_features: 910 and eps: 0.33 started ...
# 3750 issues clustered
# 3758 issues clustered
# 3763 issues clustered
# 3769 issues clustered
# Iteration for the combination max_features: 910 and eps: 0.33 started ...
# Iteration for the combination max_features: 1010 and eps: 0.33 started ...
# 3775 issues clustered
# Iteration for the combination max_features: 1010 and eps: 0.33 started ...
# Iteration for the combination max_features: 6010 and eps: 0.33 started ...
# 3780 issues clustered
# 3785 issues clustered
# 3790 issues clustered
# Iteration for the combination max_features: 6010 and eps: 0.33 started ...
# Iteration for the combination max_features: 11010 and eps: 0.33 started ...
# Iteration for the combination max_features: 16010 and eps: 0.33 started ...
# Iteration for the combination max_features: 21010 and eps: 0.33 started ...
# Iteration for the combination max_features: 50 and eps: 0.36 started ...
# Iteration for the combination max_features: 70 and eps: 0.36 started ...
# 3792 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.36 started ...
# 3796 issues clustered
# Iteration for the combination max_features: 70 and eps: 0.36 started ...
# Iteration for the combination max_features: 90 and eps: 0.36 started ...
# 3799 issues clustered
# Iteration for the combination max_features: 90 and eps: 0.36 started ...
# Iteration for the combination max_features: 110 and eps: 0.36 started ...
# 3804 issues clustered
# Iteration for the combination max_features: 110 and eps: 0.36 started ...
# Iteration for the combination max_features: 210 and eps: 0.36 started ...
# 3810 issues clustered
# 3816 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.36 started ...
# Iteration for the combination max_features: 310 and eps: 0.36 started ...
# 3822 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.36 started ...
# Iteration for the combination max_features: 410 and eps: 0.36 started ...
# 3827 issues clustered
# Iteration for the combination max_features: 410 and eps: 0.36 started ...
# Iteration for the combination max_features: 510 and eps: 0.36 started ...
# 3836 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.36 started ...
# 3841 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.36 started ...
# Iteration for the combination max_features: 610 and eps: 0.36 started ...
# 3847 issues clustered
# 3852 issues clustered
# 3860 issues clustered
# 3866 issues clustered
# Iteration for the combination max_features: 610 and eps: 0.36 started ...
# Iteration for the combination max_features: 710 and eps: 0.36 started ...
# 3871 issues clustered
# Iteration for the combination max_features: 710 and eps: 0.36 started ...
# Iteration for the combination max_features: 810 and eps: 0.36 started ...
# Iteration for the combination max_features: 910 and eps: 0.36 started ...
# 3876 issues clustered
# Iteration for the combination max_features: 910 and eps: 0.36 started ...
# Iteration for the combination max_features: 1010 and eps: 0.36 started ...
# 3881 issues clustered
# 3887 issues clustered
# Iteration for the combination max_features: 1010 and eps: 0.36 started ...
# Iteration for the combination max_features: 6010 and eps: 0.36 started ...
# 3895 issues clustered
# Iteration for the combination max_features: 6010 and eps: 0.36 started ...
# Iteration for the combination max_features: 11010 and eps: 0.36 started ...
# Iteration for the combination max_features: 16010 and eps: 0.36 started ...
# Iteration for the combination max_features: 21010 and eps: 0.36 started ...
# Iteration for the combination max_features: 50 and eps: 0.39 started ...
# Iteration for the combination max_features: 70 and eps: 0.39 started ...
# Iteration for the combination max_features: 90 and eps: 0.39 started ...
# Iteration for the combination max_features: 110 and eps: 0.39 started ...
# Iteration for the combination max_features: 210 and eps: 0.39 started ...
# 3901 issues clustered
# 3904 issues clustered
# Iteration for the combination max_features: 210 and eps: 0.39 started ...
# Iteration for the combination max_features: 310 and eps: 0.39 started ...
# 3908 issues clustered
# 3911 issues clustered
# 3916 issues clustered
# Iteration for the combination max_features: 310 and eps: 0.39 started ...
# Iteration for the combination max_features: 410 and eps: 0.39 started ...
# 3921 issues clustered
# Iteration for the combination max_features: 410 and eps: 0.39 started ...
# Iteration for the combination max_features: 510 and eps: 0.39 started ...
# 3926 issues clustered
# Iteration for the combination max_features: 510 and eps: 0.39 started ...
# Iteration for the combination max_features: 610 and eps: 0.39 started ...
# 3931 issues clustered
# 3936 issues clustered
# Iteration for the combination max_features: 610 and eps: 0.39 started ...
# Iteration for the combination max_features: 710 and eps: 0.39 started ...
# 3941 issues clustered
# 3946 issues clustered
# Iteration for the combination max_features: 710 and eps: 0.39 started ...
# Iteration for the combination max_features: 810 and eps: 0.39 started ...
# Iteration for the combination max_features: 910 and eps: 0.39 started ...
# Iteration for the combination max_features: 1010 and eps: 0.39 started ...
# 3951 issues clustered
# Iteration for the combination max_features: 1010 and eps: 0.39 started ...
# Iteration for the combination max_features: 6010 and eps: 0.39 started ...
# 3956 issues clustered
# 3962 issues clustered
# 3968 issues clustered
# Iteration for the combination max_features: 6010 and eps: 0.39 started ...
# Iteration for the combination max_features: 11010 and eps: 0.39 started ...
# Iteration for the combination max_features: 16010 and eps: 0.39 started ...
# Iteration for the combination max_features: 21010 and eps: 0.39 started ...

# %%
clustered
# Out:
#          id reporter_id severity priority      cluster  cluster_#  \
# 14     9792          82       50       30    50_0.03_0        NaN
# 26     9815          39       50       40    50_0.03_0        NaN
# 151   13425          39       50       30    50_0.03_0        NaN
# 152   13426          39       50       30    50_0.03_0        NaN
# 338   15005          39       50       30    50_0.03_0        NaN
# 806    6227           4       50       30    50_0.03_0        NaN
# 860    7474          39       50       30    50_0.03_0        NaN
# 963    9452          50       50       40    50_0.03_0        NaN
# 1025  10266          40       50       30    50_0.03_0        NaN
# 1247  11493           4       50       40    50_0.03_0        NaN
# 1277   5208          40       50       30    50_0.03_0        NaN
# 1280   5211           1       50       30    50_0.03_0        NaN
# 1315  13074          39       50       30    50_0.03_0        NaN
# 1319  13078          81       50       30    50_0.03_0        NaN
# 1565   3429          40       50       30    50_0.03_0        NaN
# 1936  13398          40       50       40    50_0.03_0        NaN
# 1938  13402          40       50       40    50_0.03_0        NaN
# 2039   7638           4       50       30    50_0.03_0        NaN
# 2105  14290         107       50       30    50_0.03_0        NaN
# 2114  14301          39       50       30    50_0.03_0        NaN
# 2596  19604          40       50       30    50_0.03_0        NaN
# 2848   4459          40       50       30    50_0.03_0        NaN
# 3137   9258          39       50       30    50_0.03_0        NaN
# 3139   9260           3       50       30    50_0.03_0        NaN
# 3257   5933          50       50       30    50_0.03_0        NaN
# 3261   5941          50       50       50    50_0.03_0        NaN
# 3264   5944           4       50       40    50_0.03_0        NaN
# 3267   5949           4       60       40    50_0.03_0        NaN
# 3296   5991           4       50       30    50_0.03_0        NaN
# 3547  16379          88       50       30    50_0.03_0        NaN
# ...     ...         ...      ...      ...          ...        ...
# 1742  14268          59       50       30  710_0.39_10        NaN
# 5704  14586          59       50       30  710_0.39_10        NaN
# 7443  14874          59       50       30  710_0.39_10        NaN
# 1906  13348          40       50       30  710_0.39_12        NaN
# 5346  17364          78       50       30  710_0.39_12        NaN
# 5647  13330          40       50       30  710_0.39_12        NaN
# 9163  14052           3       50       30  710_0.39_12        NaN
# 9164  14053           3       50       30  710_0.39_12        NaN
# 415    2095          21       50       30  1010_0.39_5        NaN
# 917     271           5       10       50  1010_0.39_5        NaN
# 4464    385           5       50       30  1010_0.39_5        NaN
# 4480    408           4       50       30  1010_0.39_5        NaN
# 4957   2232          21       50       30  1010_0.39_5        NaN
# 29     9820           1       50       30  6010_0.39_0        NaN
# 2488   8384           1       50       30  6010_0.39_0        NaN
# 5638  13311           1       50       30  6010_0.39_0        NaN
# 6330   6194           5       50       30  6010_0.39_0        NaN
# 7596   8469           1       50       30  6010_0.39_0        NaN
# 1222  11442          40       50       30  6010_0.39_1        NaN
# 4056  12733          40       50       30  6010_0.39_1        NaN
# 5722  14614          39       50       30  6010_0.39_1        NaN
# 7120  13744          40       50       30  6010_0.39_1        NaN
# 7155  13801          40       50       30  6010_0.39_1        NaN
# 7841   9725          40       50       30  6010_0.39_1        NaN
# 2195  16535          40       50       30  6010_0.39_2        NaN
# 3023  16623           1       50       30  6010_0.39_2        NaN
# 3835  13883          40       50       30  6010_0.39_2        NaN
# 5742  14655          40       50       30  6010_0.39_2        NaN
# 8115  15184          40       50       30  6010_0.39_2        NaN
# 8391  13535          40       50       30  6010_0.39_2        NaN
#
#       cluster_dbscan_silhouette_mean
# 14                          0.657621
# 26                          0.657621
# 151                         0.657621
# 152                         0.657621
# 338                         0.657621
# 806                         0.657621
# 860                         0.657621
# 963                         0.657621
# 1025                        0.657621
# 1247                        0.657621
# 1277                        0.657621
# 1280                        0.657621
# 1315                        0.657621
# 1319                        0.657621
# 1565                        0.657621
# 1936                        0.657621
# 1938                        0.657621
# 2039                        0.657621
# 2105                        0.657621
# 2114                        0.657621
# 2596                        0.657621
# 2848                        0.657621
# 3137                        0.657621
# 3139                        0.657621
# 3257                        0.657621
# 3261                        0.657621
# 3264                        0.657621
# 3267                        0.657621
# 3296                        0.657621
# 3547                        0.657621
# ...                              ...
# 1742                        0.305390
# 5704                        0.305390
# 7443                        0.305390
# 1906                        0.307982
# 5346                        0.307982
# 5647                        0.307982
# 9163                        0.307982
# 9164                        0.307982
# 415                         0.360290
# 917                         0.360290
# 4464                        0.360290
# 4480                        0.360290
# 4957                        0.360290
# 29                          0.340857
# 2488                        0.340857
# 5638                        0.340857
# 6330                        0.340857
# 7596                        0.340857
# 1222                        0.325932
# 4056                        0.325932
# 5722                        0.325932
# 7120                        0.325932
# 7155                        0.325932
# 7841                        0.325932
# 2195                        0.339281
# 3023                        0.339281
# 3835                        0.339281
# 5742                        0.339281
# 8115                        0.339281
# 8391                        0.339281
#
# [3968 rows x 7 columns]

# %%
clustered[clustered['cluster_dbscan_silhouette_mean']>=0.35]
# Out:
#          id reporter_id severity priority       cluster  cluster_#  \
# 14     9792          82       50       30     50_0.03_0        NaN
# 26     9815          39       50       40     50_0.03_0        NaN
# 151   13425          39       50       30     50_0.03_0        NaN
# 152   13426          39       50       30     50_0.03_0        NaN
# 338   15005          39       50       30     50_0.03_0        NaN
# 806    6227           4       50       30     50_0.03_0        NaN
# 860    7474          39       50       30     50_0.03_0        NaN
# 963    9452          50       50       40     50_0.03_0        NaN
# 1025  10266          40       50       30     50_0.03_0        NaN
# 1247  11493           4       50       40     50_0.03_0        NaN
# 1277   5208          40       50       30     50_0.03_0        NaN
# 1280   5211           1       50       30     50_0.03_0        NaN
# 1315  13074          39       50       30     50_0.03_0        NaN
# 1319  13078          81       50       30     50_0.03_0        NaN
# 1565   3429          40       50       30     50_0.03_0        NaN
# 1936  13398          40       50       40     50_0.03_0        NaN
# 1938  13402          40       50       40     50_0.03_0        NaN
# 2039   7638           4       50       30     50_0.03_0        NaN
# 2105  14290         107       50       30     50_0.03_0        NaN
# 2114  14301          39       50       30     50_0.03_0        NaN
# 2596  19604          40       50       30     50_0.03_0        NaN
# 2848   4459          40       50       30     50_0.03_0        NaN
# 3137   9258          39       50       30     50_0.03_0        NaN
# 3139   9260           3       50       30     50_0.03_0        NaN
# 3257   5933          50       50       30     50_0.03_0        NaN
# 3261   5941          50       50       50     50_0.03_0        NaN
# 3264   5944           4       50       40     50_0.03_0        NaN
# 3267   5949           4       60       40     50_0.03_0        NaN
# 3296   5991           4       50       30     50_0.03_0        NaN
# 3547  16379          88       50       30     50_0.03_0        NaN
# ...     ...         ...      ...      ...           ...        ...
# 116   10572           1       50       30   910_0.36_15        NaN
# 4444  10452           1       50       30   910_0.36_15        NaN
# 5436   8280          76       50       30   910_0.36_15        NaN
# 7386   9150          76       50       30   910_0.36_15        NaN
# 8423  10152           1       50       30   910_0.36_15        NaN
# 443    2192           4       50       30   1010_0.36_7        NaN
# 2311   2862           4       50       30   1010_0.36_7        NaN
# 2318   2873          42       50       30   1010_0.36_7        NaN
# 2934   3744          47       50       30   1010_0.36_7        NaN
# 5951   2525           4       50       30   1010_0.36_7        NaN
# 2537   4145          39       50       30  1010_0.36_11        NaN
# 4982   2302           4       50       30  1010_0.36_11        NaN
# 6452  12286           4       50       30  1010_0.36_11        NaN
# 7546   4598          39       50       30  1010_0.36_11        NaN
# 7638   4321          41       10       30  1010_0.36_11        NaN
# 7788   3530           4       50       30  1010_0.36_11        NaN
# 305   14934          88       50       30    310_0.39_3        NaN
# 1054  11317           4       50       30    310_0.39_3        NaN
# 2611    511           5       10       30    310_0.39_3        NaN
# 6017  18002          60       50       30    310_0.39_3        NaN
# 3019  16613          39       50       30   610_0.39_12        NaN
# 3694   4957          40       50       30   610_0.39_12        NaN
# 5679   2641           4       50       30   610_0.39_12        NaN
# 6403   3209           4       50       30   610_0.39_12        NaN
# 7276   2696           4       50       30   610_0.39_12        NaN
# 415    2095          21       50       30   1010_0.39_5        NaN
# 917     271           5       10       50   1010_0.39_5        NaN
# 4464    385           5       50       30   1010_0.39_5        NaN
# 4480    408           4       50       30   1010_0.39_5        NaN
# 4957   2232          21       50       30   1010_0.39_5        NaN
#
#       cluster_dbscan_silhouette_mean
# 14                          0.657621
# 26                          0.657621
# 151                         0.657621
# 152                         0.657621
# 338                         0.657621
# 806                         0.657621
# 860                         0.657621
# 963                         0.657621
# 1025                        0.657621
# 1247                        0.657621
# 1277                        0.657621
# 1280                        0.657621
# 1315                        0.657621
# 1319                        0.657621
# 1565                        0.657621
# 1936                        0.657621
# 1938                        0.657621
# 2039                        0.657621
# 2105                        0.657621
# 2114                        0.657621
# 2596                        0.657621
# 2848                        0.657621
# 3137                        0.657621
# 3139                        0.657621
# 3257                        0.657621
# 3261                        0.657621
# 3264                        0.657621
# 3267                        0.657621
# 3296                        0.657621
# 3547                        0.657621
# ...                              ...
# 116                         0.356961
# 4444                        0.356961
# 5436                        0.356961
# 7386                        0.356961
# 8423                        0.356961
# 443                         0.390179
# 2311                        0.390179
# 2318                        0.390179
# 2934                        0.390179
# 5951                        0.390179
# 2537                        0.408654
# 4982                        0.408654
# 6452                        0.408654
# 7546                        0.408654
# 7638                        0.408654
# 7788                        0.408654
# 305                         0.372699
# 1054                        0.372699
# 2611                        0.372699
# 6017                        0.372699
# 3019                        0.362114
# 3694                        0.362114
# 5679                        0.362114
# 6403                        0.362114
# 7276                        0.362114
# 415                         0.360290
# 917                         0.360290
# 4464                        0.360290
# 4480                        0.360290
# 4957                        0.360290
#
# [2767 rows x 7 columns]

# %%
import math
if mathclustered['cluster_#'].max().isnull():
    print 123
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-03123b86ab61> in <module>()
# ----> 1 if clustered['cluster_#'].max().isnull():
#       2     print 123
#
# AttributeError: 'float' object has no attribute 'isnull'
